# %% [markdown]
# # pandas

# %%
import pandas as pd

# %% [markdown]
# We're going to work with our forest fire dataset again from Day One.

# %% [markdown]
# #### If you are using Google Colab, you must run the next line of code. *If you are NOT using Google Colab, do NOT run the next line.*

# %%
# !wget https://raw.githubusercontent.com/aGitHasNoName/pandasBasics/main/forestfires.csv

# %% [markdown]
# <br><br>Everyone can now run the next line of code to create a DataFrame from our csv file.

# %%
df = pd.read_csv("forestfires.csv")

# %%
df.head()
# Out:
#    X  Y month  day  fuel_code  moisture_code  drought_code  \
# 0  7  5   mar  fri       86.2           26.2          94.3
# 1  7  4   oct  tue       90.6           35.4         669.1
# 2  7  4   oct  sat       90.6           43.7         686.9
# 3  8  6   mar  fri       91.7           33.3          77.5
# 4  8  6   mar  sun       89.3           51.3         102.2
#
#    initial_spread_code  temp  humidity  wind  rain  area_burned
# 0                  5.1   8.2        51   6.7   0.0          0.0
# 1                  6.7  18.0        33   0.9   0.0          0.0
# 2                  6.7  14.6        33   1.3   0.0          0.0
# 3                  9.0   8.3        97   4.0   0.2          0.0
# 4                  9.6  11.4        99   1.8   0.0          0.0

# %% [markdown]
# ## <br><br><br>Data aggregation

# %% [markdown]
# Data aggregation means taking many data points and reducing them to one number, whether it's a count, sum, mean, or other single statistic. Here are some DataFrame method functions:

# %% [markdown]
# - [`.count()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.count.html)
# - [`.sum()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)
# - [`.mean()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [`.median()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html)
# - [`.min()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.min.html)
# - [`.max()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.max.html)
# - [`.unique()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html)
# - [`.nunique()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.nunique.html)
# - [`.std()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html)   #Standard error
# - [`.var()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.var.html)   #Variance
# - And more! https://pandas.pydata.org/docs/reference/series.html#computations-descriptive-stats

# %% [markdown]
# If you use a method function on the entire dataset, it will try its best to execute the method for all columns.

# %%
df.count()
# Out:
# X                      517
# Y                      517
# month                  517
# day                    517
# fuel_code              517
# moisture_code          517
# drought_code           517
# initial_spread_code    517
# temp                   517
# humidity               517
# wind                   517
# rain                   517
# area_burned            517
# dtype: int64

# %%
df.min()
# Out:
# X                         1
# Y                         2
# month                   apr
# day                     fri
# fuel_code              18.7
# moisture_code           1.1
# drought_code            7.9
# initial_spread_code     0.0
# temp                    2.2
# humidity                 15
# wind                    0.4
# rain                    0.0
# area_burned             0.0
# dtype: object

# %%
df.sum()
# Out:
# X                                                                   2414
# Y                                                                   2223
# month                  maroctoctmarmaraugaugaugsepsepsepsepaugsepseps...
# day                    frituesatfrisunsunmonmontuesatsatsatfrimonwedf...
# fuel_code                                                        46863.3
# moisture_code                                                    57321.0
# drought_code                                                    283285.0
# initial_spread_code                                               4664.2
# temp                                                              9765.7
# humidity                                                           22897
# wind                                                              2077.1
# rain                                                                11.2
# area_burned                                                      6642.05
# dtype: object

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/0q/cqksr9q162s4_lvj5xz4q0s40000gn/T/ipykernel_73719/1660334235.py in <module>
# ----> 1 df.unique()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# <br>Not all functions will work on the entire DataFrame. Most of the time you are interested in only a subset of the data:

# %%
df["day"].unique()
# Out:
# array(['fri', 'tue', 'sat', 'sun', 'mon', 'wed', 'thu'], dtype=object)

# %%
list(df["day"].unique())
# Out:
# ['fri', 'tue', 'sat', 'sun', 'mon', 'wed', 'thu']

# %%
df["month"].nunique()
# Out:
# 12

# %%
df["temp"].var()
# Out:
# 33.7168979503096

# %% [markdown]
# ### <br><br>Exercise 1

# %% [markdown]
# Write code to find the mean humidity of the dataset:

# %%
df["humidity"].mean()
# Out:
# 44.28820116054158

# %% [markdown]
# Write code to find the coldest temperature in the dataset:

# %%
df["temp"].min()
# Out:
# 2.2

# %%
df.temp
# Out:
# 0       8.2
# 1      18.0
# 2      14.6
# 3       8.3
# 4      11.4
#        ...
# 512    27.8
# 513    21.9
# 514    21.2
# 515    25.6
# 516    11.8
# Name: temp, Length: 517, dtype: float64

# %% [markdown]
# ## <br><br>groupby

# %% [markdown]
# Often, you will want to calculate the statistics for a particular subgroup of a data column.

# %% [markdown]
# For example, let's say we want to ask if more fires happen on certain days of the week. This code will tell you the count for every column in the DataFrame except the column that you are using to group your data (i.e. "day").

# %%
df.groupby("day").count()
# Out:
#       X   Y  month  fuel_code  moisture_code  drought_code  \
# day
# fri  85  85     85         85             85            85
# mon  74  74     74         74             74            74
# sat  84  84     84         84             84            84
# sun  95  95     95         95             95            95
# thu  61  61     61         61             61            61
# tue  64  64     64         64             64            64
# wed  54  54     54         54             54            54
#
#      initial_spread_code  temp  humidity  wind  rain  area_burned
# day
# fri                   85    85        85    85    85           85
# mon                   74    74        74    74    74           74
# sat                   84    84        84    84    84           84
# sun                   95    95        95    95    95           95
# thu                   61    61        61    61    61           61
# tue                   64    64        64    64    64           64
# wed                   54    54        54    54    54           54

# %% [markdown]
# <br>We can make this easier to read by sorting the rows from lowest count to highest count. We can string multiple method functions onto our code, as long as they go in the correct logical order. We will pick any column to sort on, since they are all the same.

# %%
df.groupby("day").count().sort_values("X")
# Out:
#       X   Y  month  fuel_code  moisture_code  drought_code  \
# day
# wed  54  54     54         54             54            54
# thu  61  61     61         61             61            61
# tue  64  64     64         64             64            64
# mon  74  74     74         74             74            74
# sat  84  84     84         84             84            84
# fri  85  85     85         85             85            85
# sun  95  95     95         95             95            95
#
#      initial_spread_code  temp  humidity  wind  rain  area_burned
# day
# wed                   54    54        54    54    54           54
# thu                   61    61        61    61    61           61
# tue                   64    64        64    64    64           64
# mon                   74    74        74    74    74           74
# sat                   84    84        84    84    84           84
# fri                   85    85        85    85    85           85
# sun                   95    95        95    95    95           95

# %% [markdown]
# <br>It looks like weekends have more fires than weekdays.

# %% [markdown]
# ### <br><br>Exercise 2

# %% [markdown]
# Write code to find the mean for all the columns when grouped by month.

# %%
df.groupby("month").mean()
# Out:
#               X         Y  fuel_code  moisture_code  drought_code  \
# month
# apr    5.777778  4.222222  85.788889      15.911111     48.555556
# aug    4.483696  4.282609  92.336957     153.732609    641.077717
# dec    4.555556  5.000000  84.966667      26.122222    351.244444
# feb    5.150000  4.400000  82.905000       9.475000     54.670000
# jan    3.000000  4.500000  50.400000       2.400000     90.350000
# jul    5.218750  4.593750  91.328125     110.387500    450.603125
# jun    6.294118  4.823529  89.429412      93.382353    297.705882
# mar    4.722222  4.481481  89.444444      34.542593     75.942593
# may    5.000000  4.000000  87.350000      26.700000     93.750000
# nov    6.000000  3.000000  79.500000       3.000000    106.700000
# oct    5.866667  4.333333  90.453333      41.420000    681.673333
# sep    4.383721  4.116279  91.243023     120.922674    734.615698
#
#        initial_spread_code       temp   humidity      wind      rain  \
# month
# apr               5.377778  12.044444  46.888889  4.666667  0.000000
# aug              11.072283  21.631522  45.489130  4.086413  0.058696
# dec               3.466667   4.522222  38.444444  7.644444  0.000000
# feb               3.350000   9.635000  55.700000  3.755000  0.000000
# jan               1.450000   5.250000  89.000000  2.000000  0.000000
# jul               9.393750  22.109375  45.125000  3.734375  0.006250
# jun              11.776471  20.494118  45.117647  4.135294  0.000000
# mar               7.107407  13.083333  40.000000  4.968519  0.003704
# may               4.600000  14.650000  67.000000  4.450000  0.000000
# nov               1.100000  11.800000  31.000000  4.500000  0.000000
# oct               7.146667  17.093333  37.466667  3.460000  0.000000
# sep               8.577326  19.612209  42.843023  3.557558  0.000000
#
#        area_burned
# month
# apr       8.891111
# aug      12.489076
# dec      13.330000
# feb       6.275000
# jan       0.000000
# jul      14.369687
# jun       5.841176
# mar       4.356667
# may      19.240000
# nov       0.000000
# oct       6.638000
# sep      17.942616

# %% [markdown]
# <br><br><br><br>If you only want to see an aggregate total for one column in the DataFrame, you can add on the indexing technique we learned yesterday. With this code I will ask, What is the mean area burned on each day of the week?

# %%
df.groupby("day")[["area_burned"]].mean()
# Out:
#      area_burned
# day
# fri     5.261647
# mon     9.547703
# sat    25.534048
# sun    10.104526
# thu    16.345902
# tue    12.621719
# wed    10.714815

# %% [markdown]
# <br>Again, we can also sort the data:

# %%
df.groupby("day")[["area_burned"]].mean().sort_values("area_burned")
# Out:
#      area_burned
# day
# fri     5.261647
# mon     9.547703
# sun    10.104526
# wed    10.714815
# tue    12.621719
# thu    16.345902
# sat    25.534048

# %% [markdown]
# <br>So Saturday fires are the most destructive fires.

# %% [markdown]
# <br>We can also add some other functions to our code, like round:

# %%
df.groupby("day")[["area_burned"]].mean().round(2).sort_values("area_burned")
# Out:
#      area_burned
# day
# fri         5.26
# mon         9.55
# sun        10.10
# wed        10.71
# tue        12.62
# thu        16.35
# sat        25.53

# %% [markdown]
# ### <br><br>Exercise 3

# %% [markdown]
# Write code to count how many fires happened in each month (as a bonus, sort the results):

# %%
df.groupby("month").count().sort_values("X")
# Out:
#          X    Y  day  fuel_code  moisture_code  drought_code  \
# month
# nov      1    1    1          1              1             1
# jan      2    2    2          2              2             2
# may      2    2    2          2              2             2
# apr      9    9    9          9              9             9
# dec      9    9    9          9              9             9
# oct     15   15   15         15             15            15
# jun     17   17   17         17             17            17
# feb     20   20   20         20             20            20
# jul     32   32   32         32             32            32
# mar     54   54   54         54             54            54
# sep    172  172  172        172            172           172
# aug    184  184  184        184            184           184
#
#        initial_spread_code  temp  humidity  wind  rain  area_burned
# month
# nov                      1     1         1     1     1            1
# jan                      2     2         2     2     2            2
# may                      2     2         2     2     2            2
# apr                      9     9         9     9     9            9
# dec                      9     9         9     9     9            9
# oct                     15    15        15    15    15           15
# jun                     17    17        17    17    17           17
# feb                     20    20        20    20    20           20
# jul                     32    32        32    32    32           32
# mar                     54    54        54    54    54           54
# sep                    172   172       172   172   172          172
# aug                    184   184       184   184   184          184

# %% [markdown]
# Write code to see the mean area burned for fires in each month (as a bonus, round and sort the results):

# %%
df.groupby("month")[["area_burned"]].mean().round(2).sort_values("area_burned")
# Out:
#        area_burned
# month
# jan           0.00
# nov           0.00
# mar           4.36
# jun           5.84
# feb           6.28
# oct           6.64
# apr           8.89
# aug          12.49
# dec          13.33
# jul          14.37
# sep          17.94
# may          19.24
